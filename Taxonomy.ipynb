# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the dataset
df = pd.read_csv('taxonomic_dataset.csv')

# %%
df.head()
# Out:
#     kingdom        phylum          class       order         family  \
# 0  Animalia      Chordata       Squamata         NaN        Teiidae
# 1   Plantae  Tracheophyta  Magnoliopsida     Apiales       Apiaceae
# 2   Plantae  Tracheophyta  Magnoliopsida    Ericales      Ericaceae
# 3  Animalia    Arthropoda        Insecta  Coleoptera  Chrysomelidae
# 4  Animalia      Chordata       Squamata         NaN     Gekkonidae
#
#           genus                      species infraspecificEpithet taxonRank  \
# 0  Aspidoscelis  Aspidoscelis lineattissimus                  NaN   SPECIES
# 1        Cicuta              Cicuta maculata                  NaN   SPECIES
# 2       Calluna             Calluna vulgaris                  NaN   SPECIES
# 3    Zygogramma     Zygogramma signatipennis                  NaN   SPECIES
# 4  Hemidactylus        Hemidactylus turcicus                  NaN   SPECIES
#
#                              scientificName       verbatimScientificName  \
# 0  Aspidoscelis lineattissimus (Cope, 1878)  Aspidoscelis lineattissimus
# 1                        Cicuta maculata L.              Cicuta maculata
# 2                Calluna vulgaris (L.) Hull             Calluna vulgaris
# 3     Zygogramma signatipennis (Stål, 1859)     Zygogramma signatipennis
# 4    Hemidactylus turcicus (Linnaeus, 1758)        Hemidactylus turcicus
#
#    verbatimScientificNameAuthorship countryCode     stateProvince
# 0                               NaN          MX         Michoacán
# 1                               NaN          US        New Jersey
# 2                               NaN          FI              Oulu
# 3                               NaN          MX  Distrito Federal
# 4                               NaN          US             Texas

# %%
df.dtypes
# Out:
# kingdom                              object
# phylum                               object
# class                                object
# order                                object
# family                               object
# genus                                object
# species                              object
# infraspecificEpithet                 object
# taxonRank                            object
# scientificName                       object
# verbatimScientificName               object
# verbatimScientificNameAuthorship    float64
# countryCode                          object
# stateProvince                        object
# dtype: object

# %%
# Get the unique values of each variable
for column in df.columns:
    print(f"Unique values of {column}: {df[column].unique()}")
# Out:
# Unique values of kingdom: ['Animalia' 'Plantae' 'Fungi' 'Chromista' 'Bacteria' 'Protozoa' 'Viruses']
# Unique values of phylum: ['Chordata' 'Tracheophyta' 'Arthropoda' nan 'Mollusca' 'Ascomycota'
#  'Basidiomycota' 'Bryophyta' 'Echinodermata' 'Chlorophyta' 'Rhodophyta'
#  'Cnidaria' 'Oomycota' 'Cyanobacteria' 'Mycetozoa' 'Marchantiophyta'
#  'Ochrophyta' 'Annelida' 'Platyhelminthes' 'Charophyta' 'Porifera'
#  'Actinobacteriota' 'Proteobacteria' 'Bryozoa' 'Onychophora'
#  'Pisuviricota' 'Mucoromycota' 'Sipuncula' 'Ctenophora' 'Nematoda'
#  'Euglenozoa' 'Firmicutes' 'Blastocladiomycota' 'Anthocerotophyta'
#  'Entomophthoromycota' 'Brachiopoda' 'Chytridiomycota'
#  'Nucleocytoviricota']
# Unique values of class: ['Squamata' 'Magnoliopsida' 'Insecta' 'Aves' nan 'Gastropoda' 'Mammalia'
#  'Pezizomycetes' 'Testudines' 'Liliopsida' 'Arachnida' 'Amphibia'
#  'Polypodiopsida' 'Agaricomycetes' 'Pinopsida' 'Malacostraca' 'Bryopsida'
#  'Lecanoromycetes' 'Bivalvia' 'Lycopodiopsida' 'Asteroidea'
#  'Sordariomycetes' 'Ulvophyceae' 'Florideophyceae' 'Arthoniomycetes'
#  'Pucciniomycetes' 'Anthozoa' 'Peronosporea' 'Cyanobacteriia'
#  'Myxomycetes' 'Jungermanniopsida' 'Ophiuroidea' 'Echinoidea'
#  'Phaeophyceae' 'Polyplacophora' 'Dothideomycetes' 'Maxillopoda'
#  'Candelariomycetes' 'Hydrozoa' 'Ascidiacea' 'Polychaeta' 'Leotiomycetes'
#  'Elasmobranchii' 'Protosteliomycetes' 'Dacrymycetes' 'Diplopoda'
#  'Tremellomycetes' 'Zygnematophyceae' 'Demospongiae' 'Taphrinomycetes'
#  'Gnetopsida' 'Crocodylia' 'Marchantiopsida' 'Actinomycetia'
#  'Sphagnopsida' 'Merostomata' 'Polytrichopsida' 'Cycadopsida' 'Scyphozoa'
#  'Chilopoda' 'Holothuroidea' 'Alphaproteobacteria' 'Gymnolaemata'
#  'Collembola' 'Ustilaginomycetes' 'Clitellata' 'Crinoidea' 'Cephalopoda'
#  'Palmophyllophyceae' 'Pisoniviricetes' 'Laboulbeniomycetes'
#  'Branchiopoda' 'Eurotiomycetes' 'Mucoromycetes' 'Thaliacea'
#  'Phylactolaemata' 'Pycnogonida' 'Chlorophyceae' 'Sipunculidea'
#  'Tentaculata' 'Turbellaria' 'Chromadorea' 'Calcarea' 'Trebouxiophyceae'
#  'Scaphopoda' 'Charophyceae' 'Cubozoa' 'Geoglossomycetes' 'Euglenoidea'
#  'Bacilli' 'Xanthophyceae' 'Blastocladiomycetes' 'Anthocerotopsida'
#  'Bangiophyceae' 'Petromyzonti' 'Exobasidiomycetes' 'Entomophthoromycetes'
#  'Rhynchonellata' 'Chytridiomycetes' 'Lichinomycetes'
#  'Gammaproteobacteria' 'Megaviricetes']
# Unique values of order: [nan 'Apiales' 'Ericales' 'Coleoptera' 'Accipitriformes' 'Charadriiformes'
#  'Passeriformes' 'Lepidoptera' 'Asterales' 'Stylommatophora' 'Diptera'
#  'Proteales' 'Zygophyllales' 'Fabales' 'Lamiales' 'Sapindales'
#  'Pelecaniformes' 'Nudibranchia' 'Saxifragales' 'Artiodactyla'
#  'Hymenoptera' 'Gentianales' 'Anseriformes' 'Pezizales' 'Monotremata'
#  'Hemiptera' 'Piciformes' 'Odonata' 'Oxalidales' 'Suliformes'
#  'Ranunculales' 'Coraciiformes' 'Boraginales' 'Brassicales' 'Rosales'
#  'Asparagales' 'Dipsacales' 'Cypriniformes' 'Caryophyllales' 'Araneae'
#  'Myrtales' 'Fagales' 'Caudata' 'Equisetales' 'Malvales' 'Blattodea'
#  'Russulales' 'Littorinimorpha' 'Aquifoliales' 'Solanales' 'Malpighiales'
#  'Rodentia' 'Gruiformes' 'Orthoptera' 'Pinales' 'Decapoda' 'Cornales'
#  'Strigiformes' 'Carnivora' 'Polypodiales' 'Trombidiformes' 'Scorpiones'
#  'Geraniales' 'Agaricales' 'Psittaciformes' 'Bryales' 'Anura'
#  'Cuculiformes' 'Teloschistales' 'Apodiformes' 'Poales' 'Hypnales'
#  'Venerida' 'Lagomorpha' 'Perciformes' 'Sphenisciformes' 'Lecanorales'
#  'Columbiformes' 'Liliales' 'Lycopodiales' 'Nymphaeales' 'Ophioglossales'
#  'Nyctibiiformes' 'Polyporales' 'Valvatida' 'Celastrales' 'Osmundales'
#  'Xylariales' 'Ceratophyllales' 'Isopoda' 'Falconiformes' 'Galliformes'
#  'Alismatales' 'Boletales' 'Gleicheniales' 'Ulvales' 'Unionida'
#  'Salmoniformes' 'Corallinales' 'Arthoniales' 'Phallales' 'Magnoliales'
#  'Pectinida' 'Spinulosida' 'Pucciniales' 'Zingiberales' 'Scleractinia'
#  'Laurales' 'Peronosporales' 'Chiroptera' 'Procellariiformes'
#  'Podicipediformes' 'Santalales' 'Trichoptera' 'Commelinales' 'Dermaptera'
#  'Peltigerales' 'Vitales' 'Cyanobacteriales' 'Zygentoma' 'Diprotodontia'
#  'Caliciales' 'Neogastropoda' 'Osmeriformes' 'Anguilliformes'
#  'Esociformes' 'Salviniales' 'Actiniaria' 'Cribrariales' 'Jungermanniales'
#  'Erinaceomorpha' 'Ophiacanthida' 'Schizaeales' 'Camarodonta'
#  'Laminariales' 'Bucerotiformes' 'Chitonida' 'Tetraodontiformes'
#  'Hymenochaetales' 'Capnodiales' 'Sessilia' 'Aplysiida'
#  'Systellommatophora' 'Siluriformes' 'Cucurbitales' 'Grimmiales'
#  'Forcipulatida' 'Candelariales' 'Phasmida' 'Neuroptera' 'Piperales'
#  'Struthioniformes' 'Narcomedusae' 'Perissodactyla' 'Mantodea' 'Cetacea'
#  'Aplousobranchia' 'Siphonophorae' 'Pottiales' 'Amphinomida'
#  'Gigartinales' 'Caprimulgiformes' 'Primates' 'Psocodea' 'Scorpaeniformes'
#  'Auriculariales' 'Helotiales' 'Mytilida' 'Mecoptera' 'Myliobatiformes'
#  'Torpediniformes' 'Bartramiales' 'Cantharellales' 'Ciconiiformes'
#  'Ceratiomyxales' 'Fucales' 'Phoenicopteriformes' 'Porellales'
#  'Sebacinales' 'Heterodontiformes' 'Plocamiales' 'Dicranales' 'Ixodida'
#  'Didelphimorphia' 'Dacrymycetales' 'Echinolampadacea' 'Opiliones'
#  'Dasyuromorphia' 'Polydesmida' 'Tremellales' 'Gloeophyllales'
#  'Dioscoreales' 'Cardiida' 'Soricomorpha' 'Trogoniformes'
#  'Pleuronectiformes' 'Tricladida' 'Zygnematales' 'Poecilosclerida'
#  'Pilosa' 'Selaginellales' 'Clupeiformes' 'Verongiida' 'Carditida'
#  'Beloniformes' 'Axinellida' 'Taphrinales' 'Ostreida' 'Ephedrales'
#  'Thelephorales' 'Venturiales' 'Pedunculata' 'Lunulariales' 'Plecoptera'
#  'Megaloptera' 'Gaviiformes' 'Cyatheales' 'Paxillosida' 'Ephemeroptera'
#  'Proboscidea' 'Mycobacteriales' 'Arbacioida' 'Pandanales' 'Ostropales'
#  'Tinamiformes' 'Arecales' 'Syngnathiformes' 'Psilotales' 'Sphagnales'
#  'Xiphosurida' 'Leptothecata' 'Funariales' 'Polytrichales' 'Characiformes'
#  'Pleurobranchida' 'Sabellida' 'Scouleriales' 'Cycadales' 'Semaeostomeae'
#  'Scutigeromorpha' 'Holothuriida' 'Cingulata' 'Rhizobiales'
#  'Carcharhiniformes' 'Rhizocarpales' 'Atheliales' 'Pallaviciniales'
#  'Cyprinodontiformes' 'Umbilicariales' 'Cheilostomatida' 'Dendrochirotida'
#  'Orectolobiformes' 'Buxales' 'Geastrales' 'Corticiales' 'Stomatopoda'
#  'Cyttariales' 'Lepetellida' 'Arcida' 'Cycloneritida' 'Pertusariales'
#  'Hookeriales' 'Malacalcyonacea' 'Lepidopleurida' 'Trochida'
#  'Pteroclidiformes' 'Hypocreales' 'Casuariiformes' 'Physarales'
#  'Escalloniales' 'Hymenophyllales' 'Hypopterygiales' 'Lucinida' 'Julida'
#  'Orthotrichales' 'Suberitida' 'Dendroceratida' 'Bryopsidales'
#  'Entomobryomorpha' 'Marchantiales' 'Ustilaginales' 'Gunnerales'
#  'Cephalaspidea' 'Garryales' 'Bruniales' 'Batrachoidiformes'
#  'Gasterosteiformes' 'Cidaroida' 'Architaenioglossa' 'Scytosiphonales'
#  'Scolopendromorpha' 'Crossosomatales' 'Arhynchobdellida' 'Dictyotales'
#  'Amphipoda' 'Dilleniales' 'Scleralcyonacea' 'Comatulida' 'Myopsida'
#  'Crassiclitellata' 'Palmophyllales' 'Limida' 'Rhizostomeae'
#  'Acarosporales' 'Phaethontiformes' 'Picornavirales' 'Laboulbeniales'
#  'Trichiales' 'Stolidobranchia' 'Cladophorales' 'Rajiformes'
#  'Gobiesociformes' 'Synallactida' 'Ceramiales' 'Mycosphaerellales'
#  'Octopoda' 'Trentepohliales' 'Ctenostomatida' 'Musophagiformes'
#  'Umbraculida' 'Ellobiida' 'Lophiiformes' 'Berberidopsidales' 'Sepiida'
#  'Haplosclerida' 'Otidiformes' 'Paracryphiales' 'Glomerida' 'Diplostraca'
#  'Adapedonta' 'Symphypleona' 'Verrucariales' 'Myida' 'Aulacomniales'
#  'Halymeniales' 'Lepisosteiformes' 'Trochodendrales' 'Nidovirales'
#  'Mucorales' 'Beryciformes' 'Marattiales' 'Archaeognatha' 'Clypeasteroida'
#  'Tetraphidales' 'Anthoathecata' 'Atheriniformes' 'Pyrosomatida'
#  'Rhinopristiformes' 'Gomphales' 'Spirulida' 'Rhytismatales' 'Zoantharia'
#  'Spirobolida' 'Leotiales' 'Phyllodocida' 'Elopiformes' 'Plumatellida'
#  'Lecideales' 'Siphonariida' 'Pelliales' 'Hedwigiales' 'Pleosporales'
#  'Pantopoda' 'Sphacelariales' 'Chloranthales' 'Austrobaileyales'
#  'Peramelemorphia' 'Sphaeropleales' 'Ectocarpales' 'Corallimorpharia'
#  'Golfingiiformes' 'Coliiformes' 'Phlebobranchia' 'Apterygiformes'
#  'Salpida' 'Amphilepidida' 'Cydippida' 'Thysanoptera' 'Runcinida'
#  'Diaporthales' 'Hyracoidea' 'Polyxenida' 'Aulopiformes' 'Mugiliformes'
#  'Amiiformes' 'Rhabditida' 'Clathrinida' 'Dictyoceratida' 'Trebouxiales'
#  'Vahliales' 'Acorales' 'Dentaliida' 'Leucosolenida' 'Scandentia'
#  'Thelocarpales' 'Acipenseriformes' 'Charales' 'Carybdeida' 'Clionaida'
#  'Sirenia' 'Poduromorpha' 'Amylocorticiales' 'Rhodymeniales'
#  'Hypnodendrales' 'Geoglossales' 'Sarcoptiformes' 'Seguenziida' 'Uropygi'
#  'Splachnales' 'Velatida' 'Euglenida' 'Diadematoida' 'Acholeplasmatales'
#  'Metteniusales' 'Lithobiomorpha' 'Gadiformes' 'Agelasida' 'Oegopsida'
#  'Vaucheriales' 'Isoetales' 'Sordariales' 'Ptilidiales' 'Rhizogoniales'
#  'Geophilomorpha' 'Spatangoida' 'Eurotiales' 'Physodermatales'
#  'Phymatocerotales' 'Mycocaliciales' 'Bangiales' 'Petromyzontiformes'
#  'Rheiformes' 'Exobasidiales' 'Pseudoscorpiones' 'Chaetosphaeriales'
#  'Entomophthorales' 'Tubulidentata' 'Bryoxiphiales' 'Terebratulida'
#  'Strepsiptera' 'Chytridiales' 'Osteoglossiformes' 'Raphidioptera'
#  'Dictyosiphonales' 'Gonorynchiformes' 'Lichinales' 'Eunicida'
#  'Xanthomonadales' 'Encalyptales' 'Baeomycetales' 'Notostraca'
#  'Dermoptera' 'Diphysciales' 'Lamniformes' 'Euryalida' 'Pimascovirales'
#  'Metzgeriales' 'Albuliformes' 'Stemonitidales' 'Platyctenida'
#  'Ptychomniales' 'Steatornithiformes' 'Echinothurioida' 'Canellales'
#  'Notothyladales' 'Chaetothyriales']
# Unique values of family: ['Teiidae' 'Apiaceae' 'Ericaceae' ... 'Nemouridae' 'Arcticidae'
#  'Parasaleniidae']
# Unique values of genus: ['Aspidoscelis' 'Cicuta' 'Calluna' ... 'Batia' 'Cymothoe' 'Euphlyctis']
# Unique values of species: ['Aspidoscelis lineattissimus' 'Cicuta maculata' 'Calluna vulgaris' ...
#  'Geronticus eremita' 'Schizocosa avida' 'Lithophane pertorrida']
# Unique values of infraspecificEpithet: [nan 'capricornu' 'capitatum' ... 'davidsonii' 'cottrelli' 'trifoliata']
# Unique values of taxonRank: ['SPECIES' 'GENUS' 'SUBSPECIES' 'VARIETY' 'FORM' 'FAMILY']
# Unique values of scientificName: ['Aspidoscelis lineattissimus (Cope, 1878)' 'Cicuta maculata L.'
#  'Calluna vulgaris (L.) Hull' ... 'Geronticus eremita (Linnaeus, 1758)'
#  'Schizocosa avida (Walckenaer, 1837)'
#  'Lithophane pertorrida McDunnough, 1942']
# Unique values of verbatimScientificName: ['Aspidoscelis lineattissimus' 'Cicuta maculata' 'Calluna vulgaris' ...
#  'Geronticus eremita' 'Schizocosa avida' 'Lithophane pertorrida']
# Unique values of verbatimScientificNameAuthorship: [nan]
# Unique values of countryCode: ['MX' 'US' 'FI' 'AU' 'CO' 'NZ' 'BR' 'BW' 'CA' 'ES' 'ZA' 'PA' 'IT' 'KH'
#  'PT' 'CY' 'IN' 'CZ' 'GB' 'DE' 'BE' 'NL' 'FR' 'MH' 'TW' nan 'AR' 'AT' 'RU'
#  'TH' 'PH' 'HN' 'CH' 'SR' 'MY' 'PL' 'MN' 'UA' 'KE' 'SE' 'EC' 'LK' 'GR'
#  'HR' 'PE' 'DK' 'SG' 'KR' 'RE' 'IL' 'LT' 'UG' 'CL' 'BY' 'ID' 'GE' 'NI'
#  'CU' 'MU' 'UY' 'DZ' 'VE' 'CR' 'JP' 'HK' 'ZW' 'SJ' 'RO' 'RS' 'BF' 'GL'
#  'KP' 'TZ' 'KZ' 'FJ' 'LU' 'CN' 'NO' 'ME' 'IR' 'BM' 'IO' 'NF' 'DO' 'CF'
#  'BJ' 'MM' 'SK' 'ZM' 'AE' 'EE' 'SV' 'TN' 'AL' 'KG' 'GT' 'MA' 'MQ' 'PR'
#  'TR' 'MO' 'LB' 'BT' 'CM' 'HU' 'BZ' 'SI' 'NC' 'IE' 'BG' 'NP' 'AI' 'MG'
#  'SY' 'LI' 'BS' 'BQ' 'TT' 'LV' 'BO' 'EG' 'PW' 'MV' 'MW' 'KW' 'ET' 'AM'
#  'VN' 'KY' 'AW' 'VI' 'GF' 'AZ' 'TO' 'BB' 'SC' 'YT' 'PS' 'JO' 'IM' 'AX'
#  'HT' 'SN' 'SA' 'PF' 'CD' 'PY' 'LS' 'IS' 'FO' 'BA' 'CK' 'JM' 'UZ' 'ST'
#  'PG' 'GM' 'KN' 'NE' 'GU' 'AQ' 'SZ' 'TL' 'LC' 'MK' 'FM' 'IQ' 'VU' 'OM'
#  'CW' 'XK' 'CG' 'QA' 'GN' 'MZ' 'EH' 'SO' 'GA' 'NG' 'SB' 'CC' 'GI' 'TD'
#  'GG' 'GP' 'GH' 'AO' 'LA' 'FK' 'MT' 'GY' 'ML' 'AS' 'MC' 'YE' 'BD' 'UM'
#  'GS' 'BH' 'CX' 'SX' 'VC' 'CV' 'TM' 'CI' 'RW' 'GD' 'TF' 'VG' 'SL' 'TC'
#  'MD' 'BN' 'TG' 'JE' 'PK' 'LR' 'LY' 'DJ' 'MR' 'AF' 'GW' 'AG' 'DM' 'MP']
# Unique values of stateProvince: ['Michoacán' 'New Jersey' 'Oulu' ... 'Saipan' 'Juncos' 'Chitipa']

# %%
# Get the number of missing values in each variable
print(df.isnull().sum())
# Out:
# kingdom                                  0
# phylum                                  17
# class                                 1305
# order                                 3019
# family                                  50
# genus                                   89
# species                               1260
# infraspecificEpithet                 96847
# taxonRank                                0
# scientificName                           0
# verbatimScientificName                   0
# verbatimScientificNameAuthorship    100000
# countryCode                            306
# stateProvince                          496
# dtype: int64

# %%
#since infraspecificEpithet and verbatimScientificNameAuthorship contains no data we can drop them
df.drop(columns=['infraspecificEpithet', 'verbatimScientificNameAuthorship'], inplace=True)

# %%
df.head()
# Out:
#     kingdom        phylum          class       order         family  \
# 0  Animalia      Chordata       Squamata         NaN        Teiidae
# 1   Plantae  Tracheophyta  Magnoliopsida     Apiales       Apiaceae
# 2   Plantae  Tracheophyta  Magnoliopsida    Ericales      Ericaceae
# 3  Animalia    Arthropoda        Insecta  Coleoptera  Chrysomelidae
# 4  Animalia      Chordata       Squamata         NaN     Gekkonidae
#
#           genus                      species taxonRank  \
# 0  Aspidoscelis  Aspidoscelis lineattissimus   SPECIES
# 1        Cicuta              Cicuta maculata   SPECIES
# 2       Calluna             Calluna vulgaris   SPECIES
# 3    Zygogramma     Zygogramma signatipennis   SPECIES
# 4  Hemidactylus        Hemidactylus turcicus   SPECIES
#
#                              scientificName       verbatimScientificName  \
# 0  Aspidoscelis lineattissimus (Cope, 1878)  Aspidoscelis lineattissimus
# 1                        Cicuta maculata L.              Cicuta maculata
# 2                Calluna vulgaris (L.) Hull             Calluna vulgaris
# 3     Zygogramma signatipennis (Stål, 1859)     Zygogramma signatipennis
# 4    Hemidactylus turcicus (Linnaeus, 1758)        Hemidactylus turcicus
#
#   countryCode     stateProvince
# 0          MX         Michoacán
# 1          US        New Jersey
# 2          FI              Oulu
# 3          MX  Distrito Federal
# 4          US             Texas

# %%
len(df.columns)
# Out:
# 12

# %%
# df.describe()

# %%
import folium

# Convert non-numeric data to numeric
df['species'] = pd.to_numeric(df['species'], errors='coerce')

# Handle missing or null values
df.fillna(0, inplace=True)  # Replace NaN values with 0
# Create a choropleth map
m = folium.Map(location=[40, -100], zoom_start=4)

# Add a choropleth layer
folium.Choropleth(
    geo_data=open('countries.geojson').read(),
    data=df,
    columns=['countryCode', 'species'],
    key_on='feature.properties.name',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Number of Species'
).add_to(m)

# Display the map
m
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 12
#       9 m = folium.Map(location=[40, -100], zoom_start=4)
#      11 # Add a choropleth layer
# ---> 12 folium.Choropleth(
#      13     geo_data=open('countries.geojson').read(),
#      14     data=df,
#      15     columns=['countryCode', 'species'],
#      16     key_on='feature.properties.name',
#      17     fill_color='YlGn',
#      18     fill_opacity=0.7,
#      19     line_opacity=0.2,
#      20     legend_name='Number of Species'
#      21 ).add_to(m)
#      23 # Display the map
#      24 m
#
# File ~/.local/lib/python3.10/site-packages/folium/features.py:1638, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1631     self.geojson = TopoJson(
#    1632         geo_data,
#    1633         topojson,
#    1634         style_function=style_function,
#    1635         smooth_factor=smooth_factor,
#    1636     )
#    1637 else:
# -> 1638     self.geojson = GeoJson(
#    1639         geo_data,
#    1640         style_function=style_function,
#    1641         smooth_factor=smooth_factor,
#    1642         highlight_function=highlight_function if highlight else None,
#    1643     )
#    1645 self.add_child(self.geojson)
#    1646 if self.color_scale:
#
# File ~/.local/lib/python3.10/site-packages/folium/features.py:702, in GeoJson.__init__(self, data, style_function, highlight_function, popup_keep_highlighted, name, overlay, control, show, smooth_factor, tooltip, embed, popup, zoom_on_click, marker, **kwargs)
#     700 self.convert_to_feature_collection()
#     701 if style_function is not None:
# --> 702     self._validate_function(style_function, "style_function")
#     703     self.style_function = style_function
#     704     self.style_map: dict = {}
#
# File ~/.local/lib/python3.10/site-packages/folium/features.py:777, in GeoJson._validate_function(self, func, name)
#     774     return
#     776 test_feature = self.data["features"][0]
# --> 777 if not callable(func) or not isinstance(func(test_feature), dict):
#     778     raise ValueError(
#     779         f"{name} should be a function that accepts items from "
#     780         "data['features'] and returns a dictionary."
#     781     )
#
# File ~/.local/lib/python3.10/site-packages/folium/features.py:1618, in Choropleth.__init__.<locals>.style_function(x)
#    1617 def style_function(x):
# -> 1618     color, opacity = color_scale_fun(x)
#    1619     return {
#    1620         "weight": line_weight,
#    1621         "opacity": line_opacity,
#    (...)
#    1624         "fillColor": color,
#    1625     }
#
# File ~/.local/lib/python3.10/site-packages/folium/features.py:1590, in Choropleth.__init__.<locals>.color_scale_fun(x)
#    1588 key_of_x = self._get_by_key(x, key_on)
#    1589 if key_of_x is None:
# -> 1590     raise ValueError(f"key_on `{key_on!r}` not found in GeoJSON.")
#    1592 try:
#    1593     value_of_x = color_data[key_of_x]
#
# ValueError: key_on `'properties.name'` not found in GeoJSON.
